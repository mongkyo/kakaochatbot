# %%
import requests
import lxml
from bs4 import BeautifulSoup

# %%
def get_html(url):
    _html = ""
    resp = requests.get(url)
    if resp.status_code == 200:
        _html = resp.text
    return BeautifulSoup(_html, 'lxml')

# %%
html = get_html('https://nsulib.nsu.ac.kr/')

# %%
l = html.find_all("a")

# %%
print(len(l))
# Out:
# 247

# %%
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="남서울대학교도서관" name="description"/>
# <meta content="남서울대학교도서관, 남서울대도서관, 남서울대, 남서울대 성암기념중앙도서관" name="keyword"/>
# <meta content="copyright(c)Namseoul University Library All Rights Reserved" name="copyright"/>
# <meta content="initial-scale=1, maximum-scale=1.0, minimum-scale=1.0, width=device-width, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/><!--아이폰 전화번호 스타일 초기화-->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>남서울대학교 성암기념중앙도서관</title>
# <link href="/image/ko/local/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/image/ko/local/favicon.ico" rel="shortcut icon"/>
# <link href="/style/ko/standard/common.css" rel="stylesheet" type="text/css"/>
# <link href="/style/ko/theme/pc/main.css" rel="stylesheet"/>
# ...
